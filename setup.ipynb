# %%
import os
from shared.download import Downloader
from shared.database import Database

dl = Downloader()
dl.copy_all()

with Database() as db:
    print(type(db), db.tables)
    
    #db.import_all_tripdata()
    db.import_tripdata("data/raw/yellow_tripdata_2024-01.parquet")
# Out:
# Skip download, because file exists: data/raw/green_tripdata_2024-02.parquet
# Skip download, because file exists: data/raw/fhv_tripdata_2024-03.parquet
# Skip download, because file exists: data/raw/yellow_tripdata_2024-04.parquet
# Skip download, because file exists: data/raw/green_tripdata_2024-04.parquet
# Skip download, because file exists: data/raw/fhv_tripdata_2024-04.parquet
# Skip download, because file exists: data/raw/fhvhv_tripdata_2024-04.parquet
# Skip download, because file exists: data/raw/yellow_tripdata_2024-05.parquet
# Skip download, because file exists: data/raw/green_tripdata_2024-05.parquet
# Skip download, because file exists: data/raw/fhv_tripdata_2024-05.parquet
# Skip download, because file exists: data/raw/fhvhv_tripdata_2024-05.parquet
# Skip download, because file exists: data/raw/yellow_tripdata_2024-06.parquet
# Skip download, because file exists: data/raw/green_tripdata_2024-06.parquet
# ...
